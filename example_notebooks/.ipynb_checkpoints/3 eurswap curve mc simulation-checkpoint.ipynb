# %% [markdown]
# Note:
#
# Both SwapRateMCSimulator and SwapRatePCAEstimator require historical swap rate time series data in a specific format.
# If no explicit file path is provided to the constructor, a default CSV file will be used instead.
#
# The default dataset is located in the "curve_data" folder of the project (see "eur_swap_ts.csv" for the expected format).
#
# In the examples below, a file path is explicitly provided, although it points to the same data as the default.

# %% [markdown]
# This notebook demonstrates:
# - MC simulation of EUR swap curve. The EUR swap curve is calibrated to simulated swap rates. This transforms simulated swap rates to a set of derived
#   EUR swap discounting curves which can be used to generate PnL scenarios and calculate CVaR.

# %%
from __future__ import annotations
import os 
from pathlib import Path

# It is assumed that the notebook is executed from within the project - either root or sub folder. 
CWD_PATH = Path.cwd()
SWAP_TIME_SERIES_CSV_PATH = ""

for parent in CWD_PATH.parents:
 if (parent / "src").exists():
     SWAP_TIME_SERIES_CSV_PATH = parent / "curve_data" / "eur_swap_ts.csv"
     break       
 else:
     SWAP_TIME_SERIES_CSV_PATH = CWD_PATH / "curve_data" / "eur_swap_ts.csv"

print(CWD_PATH)
print(SWAP_TIME_SERIES_CSV_PATH)
# Out:
# C:\Users\mduba\Desktop\Programming\Python\alm_ir_hedging_prototype\example_notebooks
# C:\Users\mduba\Desktop\Programming\Python\alm_ir_hedging_prototype\curve_data\eur_swap_ts.csv

# %%
# imports 
from typing import Dict
from pathlib import Path
from datetime import datetime 
import numpy as np
import pandas as pd 
from curve_engine.swap_rate_pca_estimator import SwapRatePCAEstimator
from curve_engine.swap_rate_mc_simulator import SwapRateMCSimulator
from curve_engine.swap_curve_scenario_generator import SwapCurveScenarioGenerator

# %%
# parameters 
curve_date = datetime(2026,3,31)

# %%
# run pca from csv file with time series data for swap rates
swap_rate_pca = SwapRatePCAEstimator.from_csv( 
 swap_ts_csv_path = SWAP_TIME_SERIES_CSV_PATH 
)

# %%
# run mc simulation with scenarios for market/swap rates - 1000 scenarios, 1d shocks scaled to 30 day horizon
swap_rate_sim = SwapRateMCSimulator.from_csv(
  n_scenarios = 1000, 
  t_scale_factor = 30, 
  rng_seed = 1, 
  swap_ts_csv_path = SWAP_TIME_SERIES_CSV_PATH 
)

# %%
# create scenarios for curves calibrated to mc simulated market/swap rates 
scenarios = SwapCurveScenarioGenerator( 
    curve_date = curve_date, 
    swap_rate_sim = swap_rate_sim, 
    swap_rate_pca = swap_rate_pca
)

# %%
# calibrate the curves in each scenario of swap rates
# Note! For 1000 scenarios, this takes approx. 5-6 mins. 
scenarios.build_mc_scenario_curves( curve_id = 'eurswap' )
# Out:
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.13574640726366e-16, `time`: 0.1001s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.50531716466949e-16, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.137182868220651e-16, `time`: 0.0992s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.6703745712172888e-16, `time`: 0.0918s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.661113896766674e-16, `time`: 0.0981s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.4509528820842696e-16, `time`: 0.0963s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.586365078553314e-16, `time`: 0.1026s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.474079273925337e-16, `time`: 0.0905s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.579232650938731e-16, `time`: 0.0958s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.56787004849435e-16, `time`: 0.0965s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.1133737520284806e-16, `time`: 0.0978s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.90186609302717e-16, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.301719472756319e-16, `time`: 0.0998s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.851438160455768e-16, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.83291581434922e-16, `time`: 0.1001s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.052105084176452e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.780332905743581e-16, `time`: 0.0988s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.411736188513397e-16, `time`: 0.0958s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.287779883505857e-16, `time`: 0.1828s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.566103877493744e-16, `time`: 0.0990s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.7802181736384122e-16, `time`: 0.0967s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.714396318733685e-16, `time`: 0.0938s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.601709982571955e-16, `time`: 0.0982s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.285817151034482e-16, `time`: 0.0922s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.356883621471978e-16, `time`: 0.0966s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.147516140766904e-16, `time`: 0.0937s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.3695443244597673e-15, `time`: 0.0983s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.90248348546396e-16, `time`: 0.0988s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.6104829858097e-16, `time`: 0.1010s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.111984327066024e-16, `time`: 0.0942s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.648896709783334e-16, `time`: 0.0993s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.580211783919314e-16, `time`: 0.1010s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.182933166235002e-16, `time`: 0.1028s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.6696552957848943e-16, `time`: 0.1022s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.1565384873025453e-15, `time`: 0.1008s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.2032450197944077e-16, `time`: 0.0962s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.645208877125993e-16, `time`: 0.0976s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.805633071671916e-16, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.391522877147711e-16, `time`: 0.0957s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.1339641484134136e-16, `time`: 0.0976s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.801569646415613e-16, `time`: 0.1285s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.8637260581525666e-15, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.1800432972293657e-16, `time`: 0.0953s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.637319155853244e-16, `time`: 0.0916s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.4139504384504477e-16, `time`: 0.0958s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.2950617506597007e-16, `time`: 0.0915s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.220120784464554e-16, `time`: 0.0968s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.602461704795261e-16, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.604339910361694e-16, `time`: 0.0994s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.342770271096582e-16, `time`: 0.0928s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.413636924209334e-15, `time`: 0.0978s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.225983047080911e-16, `time`: 0.0991s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.669847664875345e-16, `time`: 0.0964s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.763286381836591e-16, `time`: 0.0920s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.748316135796873e-16, `time`: 0.0951s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.90761005397867e-16, `time`: 0.0913s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.318588111699936e-16, `time`: 0.0959s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.2228598801731e-16, `time`: 0.0932s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.299545396138593e-16, `time`: 0.0959s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.002313575626933e-15, `time`: 0.0921s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.792963483613025e-16, `time`: 0.1025s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.2189946083765986e-16, `time`: 0.0943s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.0907450849685891e-16, `time`: 0.1001s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.118440838628137e-16, `time`: 0.0918s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.157695478175317e-16, `time`: 0.0999s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.927020073989035e-16, `time`: 0.0983s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.840061179437851e-16, `time`: 0.0970s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.3459803229558746e-15, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.752400151704536e-16, `time`: 0.0992s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.480158985486223e-16, `time`: 0.0901s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.91892948108552e-15, `time`: 0.1003s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.974330844970541e-16, `time`: 0.1206s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.1921021849015777e-16, `time`: 0.1030s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.578045303701128e-16, `time`: 0.1038s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.008770636367231e-16, `time`: 0.1177s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.739319460744687e-16, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.063265482047721e-16, `time`: 0.0965s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.3073453081290905e-16, `time`: 0.0979s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.270799625997866e-16, `time`: 0.1003s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.135327033640131e-16, `time`: 0.0933s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.668660271713552e-15, `time`: 0.1004s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0148609976582154e-15, `time`: 0.1016s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.656381193903996e-16, `time`: 0.0992s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.697615386845859e-16, `time`: 0.0904s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.3674960425908445e-16, `time`: 0.1103s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.6085145297961996e-16, `time`: 0.1115s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.454353557476344e-17, `time`: 0.0996s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.66869812568148e-16, `time`: 0.0918s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.959491011844412e-16, `time`: 0.1896s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.871806810626199e-16, `time`: 0.0984s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.398389326907379e-16, `time`: 0.1006s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.095710296938629e-15, `time`: 0.1006s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.4208313145944795e-16, `time`: 0.0986s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.314030341041969e-16, `time`: 0.1024s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.580590370677067e-16, `time`: 0.1032s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.485490435979101e-16, `time`: 0.1009s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.668671760354484e-16, `time`: 0.1026s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.817361840053322e-16, `time`: 0.0926s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.034066355194998e-16, `time`: 0.0962s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.694463550372134e-16, `time`: 0.0920s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.073736300423774e-16, `time`: 0.0944s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.053499600722256e-15, `time`: 0.0937s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4423262736593753e-16, `time`: 0.0953s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.0046360854349386e-16, `time`: 0.0950s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.023733413232998e-15, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0118557042505542e-15, `time`: 0.0897s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.985961226239816e-16, `time`: 0.0979s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.399399239185251e-16, `time`: 0.0964s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.561998820655402e-16, `time`: 0.0939s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.560453413940866e-16, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.264711536311701e-16, `time`: 0.0991s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.635352697319535e-16, `time`: 0.0938s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.4934826852677856e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.402292039262554e-16, `time`: 0.0961s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.263379085818155e-16, `time`: 0.0962s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.721467960804396e-16, `time`: 0.0996s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.26406390556403e-16, `time`: 0.0987s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.114806973884626e-15, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.309178539906665e-16, `time`: 0.0996s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.858682624383165e-16, `time`: 0.0984s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.66769808831266e-16, `time`: 0.0993s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.803312206174027e-16, `time`: 0.0991s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.615772601481742e-16, `time`: 0.1244s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.584662057028017e-16, `time`: 0.0966s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.055676025949996e-16, `time`: 0.0983s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.7359382556054013e-16, `time`: 0.1029s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.588839367661881e-16, `time`: 0.0998s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.6119363698442235e-16, `time`: 0.0908s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.642252441126063e-16, `time`: 0.1010s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.6122519268499847e-16, `time`: 0.1034s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.439035479131772e-16, `time`: 0.0976s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.6300493375008597e-16, `time`: 0.1366s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.842851015499487e-16, `time`: 0.1053s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4385426197507178e-15, `time`: 0.1031s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.5277074619379526e-16, `time`: 0.1010s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.72622724370135e-16, `time`: 0.0996s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.131302272090627e-16, `time`: 0.0967s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.882924245147972e-16, `time`: 0.1086s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.034899569643717e-16, `time`: 0.0945s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4415017702429945e-15, `time`: 0.0999s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.5453186911528167e-16, `time`: 0.1040s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.1463283967517028e-15, `time`: 0.0987s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.875442497339073e-16, `time`: 0.0964s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.461708227212347e-15, `time`: 0.0952s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.827250584908722e-16, `time`: 0.0950s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.037220276211633e-16, `time`: 0.0977s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.603774580562679e-16, `time`: 0.0926s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.197509290268762e-16, `time`: 0.1006s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.815175432542733e-16, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0219775886962963e-15, `time`: 0.0954s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.784408829135567e-17, `time`: 0.0912s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.7026559018273678e-16, `time`: 0.0944s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.908693181283116e-16, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.148045281866041e-16, `time`: 0.0966s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.794623719369642e-16, `time`: 0.0917s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.670354218124834e-16, `time`: 0.1150s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.0747426555069834e-16, `time`: 0.0925s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.863888457568574e-16, `time`: 0.0979s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.61645076767304e-16, `time`: 0.0921s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.183504332054233e-16, `time`: 0.1045s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.011492970993124e-16, `time`: 0.0936s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.061956698795708e-15, `time`: 0.0976s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.815647944112575e-16, `time`: 0.0950s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.682305421758012e-16, `time`: 0.0939s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.344174535897343e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.731020137878353e-16, `time`: 0.0954s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.576156618131575e-16, `time`: 0.0911s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.583146880650312e-16, `time`: 0.0957s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.1555761956227004e-16, `time`: 0.0993s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.489291290846543e-16, `time`: 0.0928s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.367661226333247e-16, `time`: 0.0988s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.872973913160576e-16, `time`: 0.1216s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.371151908376877e-16, `time`: 0.0944s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.8826958021689393e-16, `time`: 0.1043s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.583234406565537e-16, `time`: 0.0928s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.677133598749202e-16, `time`: 0.1132s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.858549901844011e-16, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.256651020524846e-16, `time`: 0.1116s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.3349856298383143e-16, `time`: 0.0936s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.01352456411129e-16, `time`: 0.0991s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.574687754260761e-16, `time`: 0.0896s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.654999696475049e-16, `time`: 0.0950s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.5259879835454425e-16, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.458285565262564e-16, `time`: 0.0971s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.490604807289381e-16, `time`: 0.0922s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.7003381975821415e-16, `time`: 0.0979s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.8806842772438538e-16, `time`: 0.0919s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.395298086166783e-16, `time`: 0.0968s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.9274935881158533e-16, `time`: 0.0913s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.111027174289795e-15, `time`: 0.0931s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.6529464488253503e-16, `time`: 0.0921s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.039689927185817e-15, `time`: 0.0946s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.3903105475548336e-16, `time`: 0.0916s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.8505737080774626e-16, `time`: 0.0954s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.5170213963035416e-16, `time`: 0.0954s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.616575056524417e-16, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.6529582497342624e-16, `time`: 0.0948s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.915341718214225e-16, `time`: 0.0928s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.741739209232994e-16, `time`: 0.0901s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.1223995556917964e-16, `time`: 0.0932s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.762252822073263e-16, `time`: 0.0910s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.0591218345583794e-16, `time`: 0.0963s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.8919445231189583e-16, `time`: 0.0931s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.911858956712237e-16, `time`: 0.0951s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.923928895582464e-16, `time`: 0.1033s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.4513136513988383e-16, `time`: 0.0934s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.1795889984400053e-16, `time`: 0.0918s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.080827349082713e-16, `time`: 0.0937s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.576737788119902e-16, `time`: 0.0927s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.511999034229841e-16, `time`: 0.0935s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.7500136474433263e-16, `time`: 0.0976s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.66091164669651e-16, `time`: 0.0946s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.321254803995093e-16, `time`: 0.0905s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4353153511684788e-15, `time`: 0.0946s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.483053323811904e-16, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.1133255309396104e-16, `time`: 0.0946s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.840583145411467e-16, `time`: 0.0952s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.1689364598689205e-16, `time`: 0.0950s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.7741323947771606e-16, `time`: 0.0933s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.142492272567574e-16, `time`: 0.0927s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.220246142649482e-16, `time`: 0.0911s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.840433349167134e-15, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.5696300403032605e-16, `time`: 0.0974s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.767200202232242e-16, `time`: 0.0956s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0147943076809918e-15, `time`: 0.0915s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.651368090700106e-16, `time`: 0.0920s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.6028857094383346e-16, `time`: 0.0959s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.092259178059324e-16, `time`: 0.0903s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.3984698631270216e-16, `time`: 0.0955s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.6386458279716768e-16, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.521018382839853e-16, `time`: 0.0942s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.813065928294907e-16, `time`: 0.0936s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.366128916493508e-16, `time`: 0.1100s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.122411121976357e-16, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.406625632844853e-16, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.165371885073115e-16, `time`: 0.0950s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.120781375592826e-16, `time`: 0.0944s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.283021423766975e-16, `time`: 0.0920s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.241123440934427e-16, `time`: 0.0959s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.950532175872856e-16, `time`: 0.0911s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.938502455002705e-16, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.567585720100885e-16, `time`: 0.0918s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.600387567019096e-16, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.543043008281519e-16, `time`: 0.1102s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.32863547335985e-16, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4935830175847717e-15, `time`: 0.0902s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.302824897355838e-16, `time`: 0.0964s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.069796392938339e-16, `time`: 0.0907s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.815026639444538e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.4681737085221335e-16, `time`: 0.0907s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.7895042566967684e-16, `time`: 0.1089s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.6705296411398977e-16, `time`: 0.0953s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.9602551175491557e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.084020041712893e-16, `time`: 0.0948s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.465957455252773e-16, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.3081513216205294e-16, `time`: 0.0953s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4708827958881878e-16, `time`: 0.0998s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.159719914400444e-16, `time`: 0.0933s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.556668223001721e-16, `time`: 0.1042s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.310703406839414e-16, `time`: 0.0934s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.6091316562359327e-16, `time`: 0.1123s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.2675039354666875e-16, `time`: 0.0919s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.788720697965162e-16, `time`: 0.0927s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.5944884456771227e-16, `time`: 0.0953s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.3890606030535286e-16, `time`: 0.0981s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.6786666666520723e-15, `time`: 0.0933s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.443050139611515e-16, `time`: 0.1001s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.186513216204591e-16, `time`: 0.0951s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.836280863967293e-16, `time`: 0.0951s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.594679421296976e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.059411147627339e-16, `time`: 0.0950s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.746207998248759e-16, `time`: 0.0943s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.32436670701247e-16, `time`: 0.1010s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.4689312709548656e-16, `time`: 0.0945s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.501585895737906e-16, `time`: 0.0924s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.77396019150456e-16, `time`: 0.0986s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.251814095598587e-16, `time`: 0.0999s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.2521542965752358e-15, `time`: 0.0928s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.989281740088345e-16, `time`: 0.0980s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.554209184310219e-15, `time`: 0.0981s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.761572413770737e-16, `time`: 0.0962s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.800740598857616e-16, `time`: 0.0934s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.047063942765831e-16, `time`: 0.0927s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.8821600232788875e-16, `time`: 0.0923s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.815213361506774e-16, `time`: 0.0955s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.3699680169606513e-16, `time`: 0.0937s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.21331246669851e-16, `time`: 0.1000s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.189112115026608e-16, `time`: 0.0944s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.330356478818999e-16, `time`: 0.0918s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.5720447772225274e-16, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.590390061673528e-16, `time`: 0.0949s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.622659086631732e-16, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.1649334009578752e-16, `time`: 0.0926s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.0013224584001755e-16, `time`: 0.0924s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.6400288524519283e-16, `time`: 0.0928s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.0939459762154265e-16, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.092481902495158e-16, `time`: 0.0936s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.913909912361299e-16, `time`: 0.0966s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.979225654187862e-16, `time`: 0.0956s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.1004160698605585e-16, `time`: 0.0943s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.969092300756055e-16, `time`: 0.0909s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.026263080917902e-16, `time`: 0.1003s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.701883241921128e-16, `time`: 0.0906s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.056388918666103e-16, `time`: 0.0937s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.3423610308718885e-16, `time`: 0.0912s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.02024728060097e-16, `time`: 0.0936s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.08021106528556e-16, `time`: 0.0995s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.38786438742796e-16, `time`: 0.0964s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.757690752910713e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.543562021874961e-16, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.246956008725823e-16, `time`: 0.0918s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.7619882963662887e-16, `time`: 0.0953s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.562122890544536e-16, `time`: 0.0948s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.3052893858656835e-16, `time`: 0.1161s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.4756577819234635e-16, `time`: 0.1330s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.88923477954559e-16, `time`: 0.0916s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.279586474411061e-16, `time`: 0.0937s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4197925553215522e-15, `time`: 0.0950s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.3655388870035027e-15, `time`: 0.0926s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.8309881692819404e-16, `time`: 0.1049s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.339361455811701e-16, `time`: 0.0938s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.6519644966442888e-16, `time`: 0.1113s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.2727277878468467e-16, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.2238380281236105e-15, `time`: 0.0946s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.184915647184501e-16, `time`: 0.0905s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.218349580265723e-16, `time`: 0.1001s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.3885889784656903e-16, `time`: 0.1012s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4066009863494502e-15, `time`: 0.1007s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.2048576899350488e-16, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.3163790490313654e-16, `time`: 0.0987s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.561557605436549e-16, `time`: 0.0915s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.5857266585299405e-16, `time`: 0.0987s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.1417807393926633e-16, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.1295032645051624e-16, `time`: 0.0991s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.1161778432972064e-16, `time`: 0.0939s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.2011040425313373e-16, `time`: 0.0984s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.81198774356893e-17, `time`: 0.0999s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.33258997393367e-16, `time`: 0.0943s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0241562446899818e-15, `time`: 0.1001s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.09464523270798e-16, `time`: 0.0993s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.1862075471334274e-15, `time`: 0.0918s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.7577073095879713e-16, `time`: 0.0966s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.186325700955087e-16, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.825592327674315e-16, `time`: 0.1036s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.164088322512579e-16, `time`: 0.0976s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.0176509378375685e-16, `time`: 0.0927s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0825366887979606e-15, `time`: 0.0916s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.467889761707643e-16, `time`: 0.0934s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.881525923609231e-16, `time`: 0.0932s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.070123630268179e-16, `time`: 0.1305s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0083127431986366e-15, `time`: 0.0939s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.3783726394908274e-16, `time`: 0.1007s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.926549807581688e-16, `time`: 0.0912s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.060370795122543e-16, `time`: 0.0932s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.1181653169288306e-15, `time`: 0.0931s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.484516639868928e-16, `time`: 0.0923s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.297428362672762e-16, `time`: 0.0948s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.563621714071669e-16, `time`: 0.0960s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.6531878591208728e-15, `time`: 0.0906s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.550269823667471e-16, `time`: 0.0948s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.319518218737994e-16, `time`: 0.0915s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0449764014740842e-15, `time`: 0.0952s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.1026735975419473e-16, `time`: 0.0943s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.201948395021771e-16, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.691455428467801e-16, `time`: 0.0969s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.399249493318373e-16, `time`: 0.0934s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.56805195298058e-16, `time`: 0.0945s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.932554478340162e-16, `time`: 0.1033s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.4828280302899913e-16, `time`: 0.0966s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.042449655698787e-16, `time`: 0.0972s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.792270783342696e-16, `time`: 0.0969s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.789879898338429e-16, `time`: 0.0982s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.2151847072559e-16, `time`: 0.0927s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.323884391574306e-15, `time`: 0.0997s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.154775391792848e-16, `time`: 0.0933s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.8806546744051717e-16, `time`: 0.0905s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.654974830679663e-16, `time`: 0.0936s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.3824870941812546e-16, `time`: 0.0970s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4937365518495697e-15, `time`: 0.1030s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.998341986425672e-16, `time`: 0.0994s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.498281259535942e-16, `time`: 0.1064s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.793839900963665e-16, `time`: 0.0949s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.105214731693205e-16, `time`: 0.0968s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.104971180327816e-16, `time`: 0.0915s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.3260763262742774e-16, `time`: 0.0937s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.395025220153122e-16, `time`: 0.0932s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4122362921631366e-15, `time`: 0.0958s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.403416126079563e-16, `time`: 0.0912s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.617661252503048e-16, `time`: 0.0957s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.740013694653511e-16, `time`: 0.0971s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.535897368969487e-16, `time`: 0.0935s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.929276518639287e-16, `time`: 0.0908s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.978272976276011e-16, `time`: 0.0962s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.458127912678895e-16, `time`: 0.0934s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.180004704422504e-15, `time`: 0.0942s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.556529204991362e-16, `time`: 0.0933s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.605524225097458e-16, `time`: 0.0952s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.549525103854947e-15, `time`: 0.0953s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.115088571171593e-16, `time`: 0.0942s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.374813256819785e-16, `time`: 0.0922s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.2018482328567887e-16, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.376711599639991e-16, `time`: 0.0974s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.655157471571721e-16, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4301549048371145e-15, `time`: 0.0960s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.224545587965995e-16, `time`: 0.0967s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.53630542171393e-16, `time`: 0.0925s
# ...
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.3773391516229393e-16, `time`: 0.0963s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.865729329212897e-16, `time`: 0.0933s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.110798890889434e-16, `time`: 0.0942s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.0407979985779125e-16, `time`: 0.0951s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.050038824843869e-15, `time`: 0.0976s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.577238130725773e-16, `time`: 0.0957s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.160063326864672e-16, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.0536630999639362e-16, `time`: 0.0942s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.739629703232316e-16, `time`: 0.1016s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.1566529605676682e-16, `time`: 0.0921s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.847298832675318e-16, `time`: 0.0995s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.3245636094942807e-16, `time`: 0.0905s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.78417938085006e-16, `time`: 0.0934s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.774784958051152e-16, `time`: 0.0926s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.725999465370476e-16, `time`: 0.0955s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.930989790310029e-16, `time`: 0.0936s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.048792038535105e-16, `time`: 0.0962s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.701461069804863e-16, `time`: 0.0923s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0755122107670519e-15, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.467308170026428e-16, `time`: 0.0928s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.659730197768857e-16, `time`: 0.0977s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.995805691413437e-16, `time`: 0.0922s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.024763807753942e-16, `time`: 0.0958s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.6935435520815094e-16, `time`: 0.0925s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.4583743525517435e-16, `time`: 0.0946s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.898623043864792e-16, `time`: 0.0915s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.514006129586355e-16, `time`: 0.1011s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.883961256000975e-16, `time`: 0.0915s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.0078896439494673e-16, `time`: 0.0968s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.068697890194892e-16, `time`: 0.0923s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.211588413855103e-16, `time`: 0.0980s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.249074980655279e-16, `time`: 0.0962s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.9263329221357578e-16, `time`: 0.0968s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.224551176202232e-16, `time`: 0.0923s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.983180296341229e-16, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.4169269602007046e-16, `time`: 0.0953s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.096894531053381e-16, `time`: 0.0980s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.921637301254649e-16, `time`: 0.0961s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.005379628047103e-15, `time`: 0.0965s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.397689425534156e-16, `time`: 0.0974s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.748617369293603e-16, `time`: 0.0981s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.223891429618963e-16, `time`: 0.0934s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.090618814856444e-16, `time`: 0.0946s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.159928077793449e-15, `time`: 0.0961s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.926870108977775e-16, `time`: 0.0951s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.447281330409611e-16, `time`: 0.0926s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.992998657465341e-16, `time`: 0.0970s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.7112303875842444e-16, `time`: 0.0951s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.217874808130344e-16, `time`: 0.0927s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.131748071897924e-16, `time`: 0.0913s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.0067083987164055e-15, `time`: 0.0931s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0231322499064164e-16, `time`: 0.0921s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.6251191100141696e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.6072833638296848e-16, `time`: 0.0926s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.032655692776273e-16, `time`: 0.0946s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.142086923925534e-16, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.520176406655389e-16, `time`: 0.0937s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.0193372258080581e-16, `time`: 0.0966s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.241879198943515e-15, `time`: 0.0970s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.799081641506028e-16, `time`: 0.0940s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.80035248633114e-16, `time`: 0.0957s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.313628733027102e-16, `time`: 0.1094s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.491965585189542e-16, `time`: 0.1013s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.032272013763735e-16, `time`: 0.1004s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.8307118887662225e-16, `time`: 0.0962s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.5654934619024967e-16, `time`: 0.0905s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.474125596980773e-16, `time`: 0.0943s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0177295841652001e-15, `time`: 0.0922s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.417063135991477e-16, `time`: 0.0934s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.951502753928564e-16, `time`: 0.0917s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.68232321432075e-16, `time`: 0.0976s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.321874316694989e-15, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.697621015283803e-16, `time`: 0.0936s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.4766503317756543e-15, `time`: 0.0924s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.867928610901155e-16, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.518604331589324e-16, `time`: 0.0926s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.563266056532269e-16, `time`: 0.1000s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.41943822836932e-16, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.642615584235254e-16, `time`: 0.0925s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.45300966575638e-16, `time`: 0.0928s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.194429301469956e-16, `time`: 0.0929s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.3973211216630004e-15, `time`: 0.0971s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.789449671759069e-16, `time`: 0.0972s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.1500811209150646e-15, `time`: 0.0980s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.3634674481366182e-15, `time`: 0.0932s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.317869333493993e-16, `time`: 0.0970s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.852516108690428e-16, `time`: 0.0921s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.0574200414216696e-16, `time`: 0.0961s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.890334494347154e-16, `time`: 0.1030s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.696221117128221e-16, `time`: 0.0982s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.9353111510350477e-16, `time`: 0.0902s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.0525570500960555e-16, `time`: 0.0953s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.02059681664267e-16, `time`: 0.0934s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0082907726089686e-15, `time`: 0.0948s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.921894893766981e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.18754780449179e-16, `time`: 0.0945s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.176296921737214e-16, `time`: 0.0957s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.574769129004487e-16, `time`: 0.0956s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.320881508548405e-16, `time`: 0.0933s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.9623635951367984e-16, `time`: 0.0951s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.353315914762309e-16, `time`: 0.0920s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.134421242947316e-16, `time`: 0.0956s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.802965016567292e-16, `time`: 0.0911s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 8.412094147904293e-16, `time`: 0.0931s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.923752689135848e-16, `time`: 0.0935s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.712032982161622e-16, `time`: 0.0994s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.9589692738554274e-16, `time`: 0.0930s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.3831853305288067e-16, `time`: 0.0960s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 5.097497523480671e-16, `time`: 0.0924s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.7042752851612556e-16, `time`: 0.0983s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 9.984887101257247e-16, `time`: 0.0920s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.762370825700303e-16, `time`: 0.0960s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.5564064103484473e-16, `time`: 0.0918s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.309673521052197e-16, `time`: 0.0955s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.581064136010538e-16, `time`: 0.0944s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.459611365206152e-16, `time`: 0.0939s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.869036997933761e-16, `time`: 0.0953s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.8494438971364576e-16, `time`: 0.0947s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.03656963179876e-16, `time`: 0.1837s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.626877627978156e-16, `time`: 0.0936s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.3674106554931543e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.226085180643463e-16, `time`: 0.1044s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.1237333842069468e-16, `time`: 0.0946s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.64728755324598e-16, `time`: 0.0972s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.2568160752840714e-16, `time`: 0.0948s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 7.170403283418767e-16, `time`: 0.0939s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.097872642192552e-16, `time`: 0.1054s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 6.903728188996115e-16, `time`: 0.0924s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.2653963652433273e-16, `time`: 0.0941s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.695290839046656e-16, `time`: 0.0915s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 2.2755072097458025e-16, `time`: 0.0924s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.8754348009394747e-15, `time`: 0.0916s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 4.564268760279289e-16, `time`: 0.0939s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 3.744836666912581e-16, `time`: 0.0963s
# SUCCESS: `func_tol` reached after 7 iterations (levenberg_marquardt), `f_val`: 1.0109833658708564e-15, `time`: 0.1002s

# %%
# mc curve scenario attributes 
scenarios.curve_date
scenarios.mc_n_scenarios
scenarios.mc_t_scale_factor
scenarios.hist_rates
scenarios.hist_shifts
scenarios.hist_cshifts
scenarios.hist_cov_mat 
scenarios.hist_corr_mat
scenarios.sim_rates
scenarios.sim_shifts
scenarios.mc_scenarios    
scenarios.mc_scenario_curves    
scenarios.pca_eigvals
scenarios.pca_eigvecs
scenarios.pca_loadings
scenarios.sim_pc_multipliers
# Out:
#      Scenario         PC1        PC2        PC3        PC4        PC5  \
# 0           1   42.159106   2.414514  -8.328188  -0.569149   1.875678
# 1           2  -26.714762 -20.041426  -4.324316  -0.093540   4.881759
# 2           3    2.687222 -12.474451  22.354319   4.568611   0.083991
# 3           4  142.152473 -12.735915   4.640567  -2.404433  -2.395499
# 4           5  -99.931880   8.880176   4.696588   2.344046   1.214362
# ..        ...         ...        ...        ...        ...        ...
# 995       996   64.001480  19.000070  -4.305759  -0.912209  -8.466307
# 996       997 -160.084397  -7.603759  -6.696594   0.386591  21.622697
# 997       998   -2.175155  -1.605786 -13.935167   3.220912   8.235920
# 998       999   17.161090  14.809326   7.325375  -2.869595   0.252579
# 999      1000  -91.896854 -13.605195 -13.027470  10.236463  13.393643
#
#            PC6       PC7       PC8       PC9      PC10
# 0     0.514132  1.558732 -1.196780 -0.433708 -4.026122
# 1    -2.071991 -0.848954  2.904716  0.753696  0.187443
# 2    -7.566429  3.270098 -7.135585 -0.857718  4.490638
# 3     9.599881  2.670557  6.864854 -1.794660  3.940224
# 4     5.894763  2.680165 -2.317420  1.026530 -1.083055
# ..         ...       ...       ...       ...       ...
# 995   8.417770  0.660693 -4.025888  0.607281 -1.156745
# 996   3.066450  3.179821 -2.195182  1.422898  5.635364
# 997  -3.617492  1.589147 -5.921688 -0.727349 -1.019527
# 998   3.024897 -3.560887  1.569728 -1.580331 -2.051777
# 999 -10.826083 -0.143616 -0.319628  5.524477 -0.423128
#
# [1000 rows x 11 columns]
